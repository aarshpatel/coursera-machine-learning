# %%
import pandas as pd

# %%
df = pd.read_csv("ex1data1.txt", sep=",", names=["Population", "Profit"])

# %%
df.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
# %matplotlib inline
from ggplot import *

# %%
ggplot(df, aes("Population", "Profit")) + geom_point()
# Out:
# <ggplot: (276812305)>
