# %%
import pandas as pd

# %%
df = pd.read_csv("ex1data2.txt", sep=",", names=["Size", "Number of Bedrooms", "Price"], header=None)

# %%
df.head()
# Out:
#    Size  Number of Bedrooms   Price
# 0  2104                   3  399900
# 1  1600                   3  329900
# 2  2400                   3  369000
# 3  1416                   2  232000
# 4  3000                   4  539900

# %%
df_new = (df - df.mean()) / (df.std())

# %%
df_new.head()
# Out:
#        Size  Number of Bedrooms     Price
# 0  0.130010           -0.223675  0.475747
# 1 -0.504190           -0.223675 -0.084074
# 2  0.502476           -0.223675  0.228626
# 3 -0.735723           -1.537767 -0.867025
# 4  1.257476            1.090417  1.595389

# %%
def compute_cost(X, y, theta):
    inner = np.square(((np.dot(X, theta.T)) - y))
    cost = np.sum(inner) / (2 * len(X))
    return cost

def gradient_descent(X, y, theta, alpha, iters):
    J_History = []
    for i in range(iters):
        cost = compute_cost(X, y, theta)
        loss = np.dot(X, theta.T) - y
        gradient = np.dot(X.transpose(), loss)
        theta = theta - ((alpha * gradient) / (len(X)))
        J_History.append(cost)
    return J_History, theta

# %%
X = np.c_[np.ones(df_new.shape[0]), df_new.iloc[:,0:df_new.shape[1]-1]  ]
y = np.array(df_new["Price"])

thetas = np.array([0,0, 0])

print X.shape
print y.shape
print thetas.shape
# Out:
# (47, 3)
# (47,)
# (3,)

# %%
compute_cost(X, y, thetas)
# Out:
# 0.48936170212765967

# %%
J_History, theta = gradient_descent(X, y, thetas, .001, 1500)

# %%
theta
# Out:
# array([ -1.07481400e-16,   5.96969837e-01,   1.50566526e-01])

# %%
J_History
# Out:
# [0.48936170212765967,
#  0.48054910410767188,
#  0.47198587701203876,
#  0.46366461618706284,
#  0.45557814005252989,
#  0.44771948335326117,
#  0.44008189061506442,
#  0.43265880979889004,
#  0.42544388614718714,
#  0.41843095621663473,
#  0.41161404209160352,
#  0.40498734577287171,
#  0.39854524373628347,
#  0.39228228165620349,
#  0.38619316928877434,
#  0.38027277551013139,
#  0.37451612350488728,
#  0.36891838610032585,
#  0.36347488124189714,
#  0.35818106760572732,
#  0.353032540343996,
#  0.34802502695915444,
#  0.34315438330308029,
#  0.33841658969738386,
#  0.33380774717119771,
#  0.32932407381288648,
#  0.32496190123222957,
#  0.32071767112972566,
#  0.3165879319697778,
#  0.31256933575460888,
#  0.30865863489585721,
#  0.30485267918089243,
#  0.30114841283098298,
#  0.29754287164853055,
#  0.29403318025067648,
#  0.29061654938665898,
#  0.28729027333638918,
#  0.28405172738778039,
#  0.28089836539044949,
#  0.27782771738347251,
#  0.27483738729495411,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots(figsize=(12,8))  
ax.plot(np.arange(1500), J_History, 'r')  
ax.set_xlabel('Iterations')  
ax.set_ylabel('Cost')  
ax.set_title('Error vs. Training Epoch')

# %%
# Cost
